# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Read the dataset

# %%
train = pd.read_csv('used_cars_train_data.csv')
test =  pd.read_csv('used_cars_test_data.csv')

# %%
print(train.shape)
print(test.shape)
# Out:
# (6019, 12)
# (1234, 11)

# %%
train.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %%
print(train.shape)
print(test.shape)
# Out:
# (6019, 12)
# (1234, 11)

# %% [markdown]
# #### Handling Null

# %%
train.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               0
# Engine               10
# Power                10
# Seats                11
# dtype: int64

# %%
train.dropna(inplace=True)
test.dropna(inplace=True)

# %%
train.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# dtype: int64

# %% [markdown]
# #### Handling Duplicates

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test.duplicated().sum()
# Out:
# 1

# %%
test.drop_duplicates(inplace=True)
test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Data Types

# %%
train.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %%
train.head(10)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# ...

# %%
train['Brand'] = train['Name'].str.split(' ').str[0]
train['Model'] = train['Name'].str.split(' ').str[1]
train.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price    Brand   Model
# 0   1.75   Maruti   Wagon
# ...

# %%
test['Brand'] = test['Name'].str.split(' ').str[0]
test['Model'] = test['Name'].str.split(' ').str[1]

# %%
test.head(3)
# Out:
#                                         Name    Location  Year  \
# 0                    Maruti Alto K10 LXI CNG       Delhi  2014
# 1              Maruti Alto 800 2016-2019 LXI  Coimbatore  2013
# 2  Toyota Innova Crysta Touring Sport 2.4 MT      Mumbai  2017
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type      Mileage   Engine  \
# 0              40929       CNG       Manual      First  32.26 km/kg   998 CC
# 1              54493    Petrol       Manual     Second    24.7 kmpl   796 CC
# 2              34000    Diesel       Manual      First   13.68 kmpl  2393 CC
#
#        Power  Seats   Brand   Model
# 0   58.2 bhp    4.0  Maruti    Alto
# 1   47.3 bhp    5.0  Maruti    Alto
# 2  147.8 bhp    7.0  Toyota  Innova

# %%
print(train['Brand'].nunique())
print(test['Brand'].nunique())
# Out:
# 31
# 29

# %%
print(train['Model'].nunique())
print(test['Model'].nunique())
# Out:
# 209
# 161

# %%
# df_test[['Brand', 'Name', 'Model']] = df_test['name'].str.split(' ', 2, expand=True)

# %%
train.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price    Brand   Model
# 0   1.75   Maruti   Wagon
# ...

# %%
train['Engine'] = train['Engine'].str.replace(' CC','')
test['Engine'] = test['Engine'].str.replace(' CC','')

# %%
train.head(3)
# Out:
#                                Name Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG   Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option     Pune  2015              41000
# 2                      Honda Jazz V  Chennai  2011              46000
#
#   Fuel_Type Transmission Owner_Type     Mileage Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg    998  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl   1582  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl   1199   88.7 bhp    5.0
#
#    Price    Brand  Model
# 0   1.75   Maruti  Wagon
# 1  12.50  Hyundai  Creta
# 2   4.50    Honda   Jazz

# %%
train['Power'] = train['Power'].str.replace(' bhp','')
test['Power']  = test['Power'].str.replace(' bhp','')

# %%
train['Engine'] = train['Engine'].astype(float)
test['Engine'] = test['Engine'].astype(float)

# %%
train.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage  Engine  Power  Seats  Price  \
# 0       CNG       Manual      First  26.6 km/kg   998.0  58.16    5.0   1.75
# 1    Diesel       Manual      First  19.67 kmpl  1582.0  126.2    5.0  12.50
# 2    Petrol       Manual      First   18.2 kmpl  1199.0   88.7    5.0   4.50
# 3    Diesel       Manual      First  20.77 kmpl  1248.0  88.76    7.0   6.00
# 4    Diesel    Automatic     Second   15.2 kmpl  1968.0  140.8    5.0  17.74
#
#      Brand   Model
# 0   Maruti   Wagon
# 1  Hyundai   Creta
# ...

# %%
train['Power'] = train['Power'].astype(float)
# test['Power'] = test['Power'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 train['Power'] = train['Power'].astype(float)
#       2 # test['Power'] = test['Power'].astype(float)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
train['Power'].unique()
# Out:
# array(['58.16', '126.2', '88.7', '88.76', '140.8', '55.2', '63.1',
#        '171.5', '103.6', '74', '103.25', '116.3', '187.7', '115',
#        '175.56', '98.6', '83.8', '167.62', '190', '88.5', '177.01', '80',
#        '67.1', '102', '108.45', '138.1', '184', '179.5', '103.5', '64',
#        '82', '254.8', '73.9', '46.3', '37.5', '77', '82.9', '149.92',
#        '138.03', '112.2', '163.7', '71', '105', '174.33', '75', '103.2',
#        '53.3', '78.9', '147.6', '147.8', '68', '186', '170', '69', '140',
#        '78', '194', '500', '108.5', '86.8', '187.74', 'null', '132',
#        '86.7', '73.94', '117.3', '218', '168.5', '89.84', '110', '90',
#        '82.85', '67', '241.4', '35', '270.9', '126.32', '73', '130',
#        '100.6', '150', '75.94', '215', '107.3', '37.48', '120', '178',
#        '152', '91.1', '85.80', '362.07', '121.3', '143', '81.80', '171',
#        '76.8', '103.52', '444', '362.9', '67.06', '120.7', '258', '81.86',
# ...

# %%
train[train['Power']=='null'].shape
# Out:
# (103, 14)

# %%
train['Power'] = train['Power'].replace('null','0.0000')
test['Power'] = test['Power'].replace('null','0.0000')

# %%
train['Power'] = train['Power'].astype(float)
test['Power'] = test['Power'].astype(float)

# %%
train.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# Brand                 object
# Model                 object
# dtype: object

# %%
def convert_mileage(x):
    if x.endswith('km/kg'):
        return float(x.split(' ')[0])*1.8
    elif x.endswith('kmpl'):
        return float(x.split(' ')[0])
    
# 1kg = 1.8L

# %%
train['Mileage'] = train['Mileage'].apply(convert_mileage)

# %%
train.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0       CNG       Manual      First    47.88   998.0   58.16    5.0   1.75
# 1    Diesel       Manual      First    19.67  1582.0  126.20    5.0  12.50
# 2    Petrol       Manual      First    18.20  1199.0   88.70    5.0   4.50
# 3    Diesel       Manual      First    20.77  1248.0   88.76    7.0   6.00
# 4    Diesel    Automatic     Second    15.20  1968.0  140.80    5.0  17.74
#
#      Brand   Model
# 0   Maruti   Wagon
# 1  Hyundai   Creta
# ...

# %%
test['Mileage'] = test['Mileage'].apply(convert_mileage)

# %%
test.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Brand                 object
# Model                 object
# dtype: object

# %% [markdown]
# #### EDA - Insights - Analysis
#
# 1) Plot Top N Brand wise highest Avg Price<br>
# 2) Plot Year wise Avg Price in descending order<br>
# 3) Rank top 3 Brand per Fuel Type with highest mean Price. Also display the corresponding Car_Brand.<br>
# 4) Rank top N Car_Brand per location based on the Count of Car Brand<br>
# 5) Find Car_Model wise Avg Price representing only those Car_Models whose avg_price is greater
# than avg price of overall average of Car_Model wise Avg Price<br>

# %% [markdown]
# #### Q3)

# %%
w1 = train[['Brand','Fuel_Type','Price']]

# %%
w2 = w1.groupby(['Fuel_Type','Brand'])['Price'].mean().reset_index()
# w2
w2 = w2.sort_values(['Fuel_Type','Price'],ascending=[True,False])
w2
# Out:
#    Fuel_Type          Brand       Price
# 1        CNG         Maruti    3.551837
# 3        CNG         Toyota    3.350000
# 0        CNG        Hyundai    3.262500
# 2        CNG           Tata    3.250000
# 24    Diesel        Porsche   57.440000
# 17    Diesel           Land   39.861053
# 15    Diesel         Jaguar   34.586944
# 20    Diesel  Mercedes-Benz   28.775941
# 5     Diesel           Audi   25.834608
# 6     Diesel            BMW   25.825214
# 21    Diesel           Mini   24.690000
# 14    Diesel          Isuzu   20.000000
# 31    Diesel          Volvo   18.802857
# 16    Diesel           Jeep   18.787857
# 29    Diesel         Toyota   12.916302
# 22    Diesel     Mitsubishi   12.543636
# 13    Diesel          ISUZU   12.045000
# 9     Diesel          Force    9.333333
# 18    Diesel       Mahindra    8.165900
# 10    Diesel           Ford    7.580490
# 26    Diesel          Skoda    7.391596
# 12    Diesel        Hyundai    7.066854
# ...

# %%
w2['Rank'] = w2.groupby('Fuel_Type').cumcount() + 1
w2
# Out:
#    Fuel_Type          Brand       Price  Rank
# 1        CNG         Maruti    3.551837     1
# 3        CNG         Toyota    3.350000     2
# 0        CNG        Hyundai    3.262500     3
# 2        CNG           Tata    3.250000     4
# 24    Diesel        Porsche   57.440000     1
# 17    Diesel           Land   39.861053     2
# 15    Diesel         Jaguar   34.586944     3
# 20    Diesel  Mercedes-Benz   28.775941     4
# 5     Diesel           Audi   25.834608     5
# 6     Diesel            BMW   25.825214     6
# 21    Diesel           Mini   24.690000     7
# 14    Diesel          Isuzu   20.000000     8
# 31    Diesel          Volvo   18.802857     9
# 16    Diesel           Jeep   18.787857    10
# 29    Diesel         Toyota   12.916302    11
# 22    Diesel     Mitsubishi   12.543636    12
# 13    Diesel          ISUZU   12.045000    13
# 9     Diesel          Force    9.333333    14
# 18    Diesel       Mahindra    8.165900    15
# ...

# %%
top3_brand_per_fuel_type = w2[w2['Rank'] <= 3]
top3_brand_per_fuel_type
# Out:
#    Fuel_Type        Brand       Price  Rank
# 1        CNG       Maruti    3.551837     1
# 3        CNG       Toyota    3.350000     2
# 0        CNG      Hyundai    3.262500     3
# 24    Diesel      Porsche   57.440000     1
# 17    Diesel         Land   39.861053     2
# 15    Diesel       Jaguar   34.586944     3
# 32       LPG      Hyundai    2.630000     1
# 33       LPG       Maruti    2.344000     2
# 45    Petrol  Lamborghini  120.000000     1
# 43    Petrol       Jaguar   65.040000     2
# 36    Petrol      Bentley   59.000000     3

# %% [markdown]
# ### Q4) Rank top N Car_Brand per location based on the Count of Car Brand

# %%
r1 = train[['Brand','Location']]

# %%
r2 = r1.groupby(['Location','Brand'])['Brand'].count().reset_index(name='Count')
r2 = r2.sort_values(['Location','Count'],ascending=[True,False])
r2
# Out:
#       Location    Brand  Count
# 8    Ahmedabad   Maruti     50
# 5    Ahmedabad  Hyundai     48
# 4    Ahmedabad    Honda     26
# 15   Ahmedabad   Toyota     18
# 1    Ahmedabad      BMW     15
# ..         ...      ...    ...
# 237       Pune   Jaguar      2
# 243       Pune     Mini      2
# 252       Pune    Volvo      2
# 238       Pune     Jeep      1
# 248       Pune    Smart      1
#
# [253 rows x 3 columns]

# %%
r2['Rank'] = r2.groupby('Location').cumcount() + 1
r2
# Out:
#       Location    Brand  Count  Rank
# 8    Ahmedabad   Maruti     50     1
# 5    Ahmedabad  Hyundai     48     2
# 4    Ahmedabad    Honda     26     3
# 15   Ahmedabad   Toyota     18     4
# 1    Ahmedabad      BMW     15     5
# ..         ...      ...    ...   ...
# 237       Pune   Jaguar      2    20
# 243       Pune     Mini      2    21
# 252       Pune    Volvo      2    22
# 238       Pune     Jeep      1    23
# 248       Pune    Smart      1    24
#
# [253 rows x 4 columns]

# %%
N = 4
res_q4 = r2[r2['Rank']<=N]
res_q4
# Out:
#        Location          Brand  Count  Rank
# 8     Ahmedabad         Maruti     50     1
# 5     Ahmedabad        Hyundai     48     2
# 4     Ahmedabad          Honda     26     3
# 15    Ahmedabad         Toyota     18     4
# 24    Bangalore        Hyundai     79     1
# 29    Bangalore  Mercedes-Benz     34     2
# 18    Bangalore           Audi     32     3
# 28    Bangalore         Maruti     32     4
# 53      Chennai         Maruti     94     1
# 49      Chennai        Hyundai     79     2
# 47      Chennai           Ford     46     3
# 61      Chennai         Toyota     42     4
# 71   Coimbatore        Hyundai    135     1
# 77   Coimbatore         Maruti     94     2
# 64   Coimbatore           Audi     50     3
# 78   Coimbatore  Mercedes-Benz     48     4
# 100       Delhi         Maruti    114     1
# 95        Delhi        Hyundai     89     2
# 109       Delhi         Toyota     67     3
# 94        Delhi          Honda     65     4
# ...

# %% [markdown]
# #### Q5)  Find Car_Model wise Avg Price representing only those Car_Models whose avg_price is greater than avg price of overall average of Car_Model wise Avg Price

# %%
s1 = train.groupby(['Model'])['Price'].mean()
s1
# Out:
# Model
# 1          16.740000
# 1000        0.850000
# 3          18.138469
# 5          25.621111
# 6          45.737143
#              ...
# Zen         1.386552
# Zest        4.615714
# i10         2.989167
# i20         5.092146
# redi-GO     3.008333
# Name: Price, Length: 209, dtype: float64

# %%
s1.mean()
# Out:
# 14.641772192217642

# %%
s2 = s1[s1>s1.mean()]
s2
# Out:
# Model
# 1       16.740000
# 3       18.138469
# 5       25.621111
# 6       45.737143
# 7       40.076154
#           ...
# XC90    23.615000
# XE      37.500000
# XF      30.313333
# XJ      63.898333
# Z4      44.270000
# Name: Price, Length: 63, dtype: float64

# %%
s2.shape
# Out:
# (63,)

# %% [markdown]
# #### EDA
# Boxplot, Countplot, Distplot

# %%
cat_cols = train.dtypes[train.dtypes=='object'].index
num_cols = train.dtypes[train.dtypes!='object'].index
print(cat_cols)
print(num_cols)
# Out:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Brand',
#        'Model'],
#       dtype='object')
# Index(['Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
plt.figure(figsize=(12,15))
for i in range(len(num_cols)):
    plt.subplot(3,3,i+1)
    sns.boxplot(x=train[num_cols[i]])
    plt.title(f'Boxplot for {num_cols[i]}')
plt.show()

# %%
train['Seats'].value_counts()
# Out:
# 5.0     5012
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64

# %%
num_cols
# Out:
# Index(['Year', 'Kilometers_Driven', 'Mileage', 'Engine', 'Power', 'Seats',
#        'Price'],
#       dtype='object')

# %%
def outlier_handling(x):              
    x = x.clip(lower=x.quantile(0.01))
    x = x.clip(upper=x.quantile(0.99))
    return x

# %%
cols = ['Kilometers_Driven', 'Mileage', 'Engine', 'Power','Price']
train[cols] = train[cols].apply(outlier_handling)

# %%
plt.figure(figsize=(12,15))
for i in range(len(num_cols)):
    plt.subplot(3,3,i+1)
    sns.boxplot(x=train[num_cols[i]])
    plt.title(f'Boxplot for {num_cols[i]}')
plt.show()

# %% [markdown]
# #### Correlation

# %%
corr = train.corr()

plt.figure(figsize=(12,12))
sns.heatmap(corr,annot=True,cmap='RdBu')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11364\1800383264.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = train.corr()

# %% [markdown]
# #### Encoding

# %%
cat_cols
# Out:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Brand',
#        'Model'],
#       dtype='object')

# %%
for i in cat_cols:
    print(f'Feature {i}')
    print(f'{train[i].nunique()}')
# Out:
# Feature Name
# 1855
# Feature Location
# 11
# Feature Fuel_Type
# 4
# Feature Transmission
# 2
# Feature Owner_Type
# 4
# Feature Brand
# 31
# Feature Model
# 209

# %% [markdown]
# #### LabeEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
train.drop('Name',axis=1,inplace=True)
test.drop('Name',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 train.drop('Name',axis=1,inplace=True)
#       2 test.drop('Name',axis=1,inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
train.columns
# Out:
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Price', 'Brand',
#        'Model'],
#       dtype='object')

# %%
cat_cols = train.dtypes[train.dtypes=='object'].index
print(cat_cols)
# Out:
# Index(['Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Brand',
#        'Model'],
#       dtype='object')

# %%
for i in cat_cols:
    train[i] = lb.fit_transform(train[i])
    test[i] = lb.fit_transform(test[i])

# %%
print(train.columns)
print(test.columns)
# Out:
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Price', 'Brand',
#        'Model'],
#       dtype='object')
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Brand', 'Model'],
#       dtype='object')

# %%
train.dtypes
# Out:
# Location               int32
# Year                   int64
# Kilometers_Driven    float64
# Fuel_Type              int32
# Transmission           int32
# Owner_Type             int32
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# Brand                  int32
# Model                  int32
# dtype: object

# %%
train1 = train.copy()
test1 = test.copy()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split

# %%
print(train1.shape)
print(test1.shape)

print(train.shape)
print(test.shape)
# Out:
# (5975, 13)
# (1223, 12)
# (5975, 13)
# (1223, 12)

# %% [markdown]
# #### Select x and y

# %%
x = train1.drop(['Price'],axis=1)
y = train1['Price']
print(x.shape)
print(y.shape)
# Out:
# (5975, 12)
# (5975,)

# %% [markdown]
# #### OLS Model

# %%
import statsmodels.api as sm

# %%
x1 = x.copy()
y1 = y.copy()

# %%
x1 = sm.add_constant(x1)
ols_m1 = sm.OLS(y1,x1).fit()
ols_m1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     1282.
# Date:                Fri, 29 Sep 2023   Prob (F-statistic):               0.00
# Time:                        14:46:40   Log-Likelihood:                -18606.
# No. Observations:                5975   AIC:                         3.724e+04
# Df Residuals:                    5962   BIC:                         3.733e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
x2 = x.drop('Owner_Type',axis=1)
y2 = y.copy()

# %%
x2 = sm.add_constant(x2)
ols_m2 = sm.OLS(y2,x2).fit()
ols_m2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.721
# Model:                            OLS   Adj. R-squared:                  0.720
# Method:                 Least Squares   F-statistic:                     1399.
# Date:                Fri, 29 Sep 2023   Prob (F-statistic):               0.00
# Time:                        14:47:46   Log-Likelihood:                -18607.
# No. Observations:                5975   AIC:                         3.724e+04
# Df Residuals:                    5963   BIC:                         3.732e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
print('OLS model -1')
print('R2',ols_m1.rsquared)
print('R2_adj',ols_m1.rsquared_adj)

print('OLS model -2')
print('R2',ols_m2.rsquared)
print('R2_adj',ols_m2.rsquared_adj)
# Out:
# OLS model -1
# R2 0.720743344931411
# R2_adj 0.7201812718249329
# OLs model -2
# R2 0.7206965905468918
# R2_adj 0.7201813570228295

# %% [markdown]
# #### Split data into train and test

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4182, 12)
# (1793, 12)
# (4182,)
# (1793,)

# %%
x_train.columns
# Out:
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Brand', 'Model'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
def eval_model(ytest,ypred):
    mae = mean_absolute_error(ytest,ypred)
    mse = mean_squared_error(ytest,ypred)
    rmse = mean_squared_error(ytest,ypred,squared=False)
    return {'MAE':mae,'MSE':mse,'RMSE':rmse}

def model_res(model,x_train,x_test,y_train,y_test,ypred,mname):
    train_r2 = model.score(x_train,y_train)
    test_r2 = model.score(x_test,y_test)
    w = eval_model(y_test,ypred)
    res_metrics = {'Train_R2':train_r2,'Test_R2':test_r2,'Test_MSE':w['MSE'],
                    'Test_RMSE':w['RMSE'],'Test_MAE':w['MAE']}
    res = pd.DataFrame(res_metrics, index=[mname]) 
    return res, res_metrics

# %%
lr1 = LinearRegression()
lr1.fit(x_train,y_train)
ypred_lr1 = lr1.predict(x_test)

# %%
lr1_df ,lr1_res = model_res(lr1,x_train,x_test,y_train,y_test,ypred_lr1,'Lin_Reg1')
print(lr1_res)
lr1_df
# Out:
# {'Train_R2': 0.7229021366759499, 'Test_R2': 0.7146540595162535, 'Test_MSE': 33.04310086411272, 'Test_RMSE': 5.748312871105115, 'Test_MAE': 3.689746878124971}
#           Train_R2   Test_R2   Test_MSE  Test_RMSE  Test_MAE
# Lin_Reg1  0.722902  0.714654  33.043101   5.748313  3.689747

# %% [markdown]
# #### DT

# %%
dt1 = DecisionTreeRegressor(max_depth=7,min_samples_split=10)
dt1.fit(x_train,y_train)
ypred_dt1 = dt1.predict(x_test)

# %%
dt1_df ,dt1_res = model_res(dt1,x_train,x_test,y_train,y_test,ypred_dt1,'DTree_Reg1')
print(dt1_res)
dt1_df
# Out:
# {'Train_R2': 0.9246815338056545, 'Test_R2': 0.8668861855531129, 'Test_MSE': 15.414598818958197, 'Test_RMSE': 3.926142995225492, 'Test_MAE': 1.9743031192213654}
#             Train_R2   Test_R2   Test_MSE  Test_RMSE  Test_MAE
# DTree_Reg1  0.924682  0.866886  15.414599   3.926143  1.974303

# %% [markdown]
# #### RF

# %%
rf1 = RandomForestRegressor(n_estimators=80,max_depth=8,min_samples_split=10)
rf1.fit(x_train,y_train)
ypred_rf1 = rf1.predict(x_test)

# %%
rf1_df ,rf1_res = model_res(rf1,x_train,x_test,y_train,y_test,ypred_rf1,'RF_Reg1')
print(rf1_res)
rf1_df
# Out:
# {'Train_R2': 0.9520700833597212, 'Test_R2': 0.9155822439762427, 'Test_MSE': 9.775588264147604, 'Test_RMSE': 3.1265937158747703, 'Test_MAE': 1.5615881038684332}
#          Train_R2   Test_R2  Test_MSE  Test_RMSE  Test_MAE
# RF_Reg1   0.95207  0.915582  9.775588   3.126594  1.561588

# %% [markdown]
# #### XGBoost

# %%
from xgboost import XGBRegressor

# %%
xgb1 = XGBRegressor()
xgb1.fit(x_train,y_train)
ypred_xgb1 = xgb1.predict(x_test)

# %%
xgb1_df ,xgb1_res = model_res(xgb1,x_train,x_test,y_train,y_test,ypred_xgb1,'XGB_Reg1')
print(xgb1_res)
xgb1_df
# Out:
# {'Train_R2': 0.9972427586954299, 'Test_R2': 0.9376654359374911, 'Test_MSE': 7.218351465404158, 'Test_RMSE': 2.6866989904721663, 'Test_MAE': 1.2066243871310407}
#           Train_R2   Test_R2  Test_MSE  Test_RMSE  Test_MAE
# XGB_Reg1  0.997243  0.937665  7.218351   2.686699  1.206624

# %%
all_res = pd.concat([lr1_df,dt1_df,rf1_df,xgb1_df])
all_res
# Out:
#             Train_R2   Test_R2   Test_MSE  Test_RMSE  Test_MAE
# Lin_Reg1    0.722902  0.714654  33.043101   5.748313  3.689747
# DTree_Reg1  0.924682  0.866886  15.414599   3.926143  1.974303
# RF_Reg1     0.952070  0.915582   9.775588   3.126594  1.561588
# XGB_Reg1    0.997243  0.937665   7.218351   2.686699  1.206624

# %%
xgb_reg2 = XGBRegressor(n_estimators =70,max_depth=5,alpha=0.3,eta=0.2)
xgb_reg2.fit(x_train,y_train)
ypred_xgb_reg2 = xgb_reg2.predict(x_test)

# %%
xgb2_df ,xgb2_res = model_res(xgb_reg2,x_train,x_test,y_train,y_test,ypred_xgb_reg2,'XGB_Reg2')
print(xgb2_res)
xgb2_df
# Out:
# {'Train_R2': 0.9856174296952603, 'Test_R2': 0.9367507318090762, 'Test_MSE': 7.324274334763338, 'Test_RMSE': 2.706339656207871, 'Test_MAE': 1.284099321625689}
#           Train_R2   Test_R2  Test_MSE  Test_RMSE  Test_MAE
# XGB_Reg2  0.985617  0.936751  7.324274    2.70634  1.284099

# %%
from sklearn.model_selection import GridSearchCV

# %%
params_xgb = {'n_estimators': [70,80,90,100],
             'alpha': [0.3,0.4,0.5,0.7,0.8],
             'eta': [0.1,0.2,0.3]}

# %%
xgb_base = XGBRegressor()
gs_xgb = GridSearchCV(estimator=xgb_base,param_grid=params_xgb,scoring='r2',cv=5)
gs_xgb.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
print(gs_xgb.best_score_)
print(gs_xgb.best_params_)
print(gs_xgb.best_estimator_)
# Out:
# 0.9343451518257346
# {'alpha': 0.8, 'eta': 0.1, 'n_estimators': 100}
# XGBRegressor(alpha=0.8, base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False, eta=0.1,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.100000001, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, ...)

# %% [markdown]
# #### Final Model

# %%
xgb_final = XGBRegressor(n_estimators =70,max_depth=5,alpha=0.3,eta=0.2)
xgb_final.fit(x,y)
# Out:
# XGBRegressor(alpha=0.3, base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False, eta=0.2,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.200000003, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=5, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=70, n_jobs=0,
#              num_parallel_tree=1, ...)

# %% [markdown]
# #### Prediction on test data

# %%
print(x.columns)
print(test1.columns)
print(x.shape)
print(test1.shape)
# Out:
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Brand', 'Model'],
#       dtype='object')
# Index(['Location', 'Year', 'Kilometers_Driven', 'Fuel_Type', 'Transmission',
#        'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats', 'Brand', 'Model'],
#       dtype='object')
# (5975, 12)
# (1222, 12)

# %%
ypred_test = xgb_final.predict(test1)

# %%
submission = pd.DataFrame({'Index':list(range(len(test1))),'Prediction':ypred_test})
submission.head(10)
# Out:
#    Index  Prediction
# 0      0    2.491357
# 1      1    2.351357
# 2      2   16.639444
# 3      3    3.984019
# 4      4    4.114622
# 5      5   13.312112
# 6      6   20.048235
# 7      7    4.332278
# 8      8    3.274728
# 9      9   12.057283

# %%
### State  value_counts
#    A        658
#    B        523
#    C        87
#    D        45
